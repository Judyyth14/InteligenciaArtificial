# %% [markdown]
# <a href="https://colab.research.google.com/github/Judyyth14/InteligenciaArtificial/blob/main/EjemploPractica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejemplo de la Practica 1

# %%
import tensorflow as tf
import numpy as np

# %%
centimetros = np.array([-10, 0, 10, 20, 30], dtype=float)
metros = np.array([7, 25, 35, 45, 65], dtype=float)

# %%
#capa = tf.keras.layers.Dense(units=1, input_shape=[1])
#modelo = tf.keras.Sequential([capa])
oculta1 = tf.keras.layers.Dense(units=3, input_shape=[1])
oculta2 = tf.keras.layers.Dense(units=3)
salida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([oculta1, oculta2, salida])

# %%
modelo.compile(
    loss='mean_squared_error'
)

# %%
print("comenzando estrenamiento..")
historial=modelo.fit(centimetros,metros,epochs=1000, verbose=False)
print("Modelo entrenado!!")
# Out:
# comenzando estrenamiento..
# Modelo entrenado!!

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("Realizar una predicción!!!")
resultado = modelo.predict([100.0])
print("El resultado es" + str(resultado)+"M")
# Out:
# Realizar una predicción!!!
# 1/1 [==============================] - 0s 488ms/step
# El resultado es[[186.04784]]M
